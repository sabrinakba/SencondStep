# %%
# To create interactive plots
import plotly.graph_objects as go
import json
import pandas as pd
import nltk
from os import listdir
from os.path import isfile, join
import seaborn as sns
from tqdm import tqdm
import glob
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import os
import string
from nltk.stem import WordNetLemmatizer
from pattern.en import tag
from nltk.corpus import wordnet as wn
import warnings
import scipy.sparse as sp 
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from collections import Counter
from nltk.corpus import reuters
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
import nltk.data
import math
import re
from nltk import word_tokenize, pos_tag
from nltk.corpus import wordnet as wn
import numpy as np
import pandas as pd
import scipy as sc
stop_words = stopwords.words('english')
ideal_sent_length = 20.0
stemmer = SnowballStemmer("english")
import re
from urllib.request import urlopen
#import gensim 
import numpy as np 
from time import time  # To time our operations
from collections import defaultdict  # For word frequency
import re
import spacy  # For preprocessing

import logging  # Setting up the loggings to monitor gensim

import spacy
import joblib
from tqdm import tqdm
import seaborn as sb
from matplotlib import pyplot as plt

wnl = WordNetLemmatizer()

# %%
res=pd.read_csv('sabrina.csv')
res.head()
# Out:
#                                    paper_id  \
# 0  004f0f8bb66cf446678dc13cf2701feec4f36d76
# 1  013d9d1cba8a54d5d3718c229b812d7cf91b6c89
# 2  01d162d7fae6aaba8e6e60e563ef4c2fca7b0e18
# 3  04030bba3035a58c7725ae267973206f6eb6c0b4
# 4  05d47dd5b46f86428de058db4ecc8bca76a9ad16
#
#                                             abstract  \
# 0                                                NaN
# 1  Background: A novel coronavirus (2019-nCoV) em...
# 2  Faced with the current large-scale public heal...
# 3  The recent outbreak of infections by the 2019 ...
# 4                                                NaN
#
#                                            body_text  \
# 0  The 2019-nCoV epidemic has spread across China...
# 1  In December 2019, a cluster of patients with p...
# 2  The sudden outbreak of the new coronavirus (SA...
# 3  Since the beginning of 2020, a surging number ...
# 4  The world is currently faced with a pandemic o...
#
#                                                title source_x  \
# 0  Healthcare-resource-adjusted vulnerabilities t...  medrxiv
# 1  Assessing spread risk of Wuhan novel coronavir...  medrxiv
# 2  TWIRLS, an automated topic-wise inference meth...  medrxiv
# 3  Development and Evaluation of A CRISPR-based D...  medrxiv
# 4  Development of CRISPR as a prophylactic strate...  biorxiv
#
#                            doi pmcid  pubmed_id  license publish_time  \
# 0  10.1101/2020.02.11.20022111   NaN        NaN  medrvix   2020-02-12
# 1  10.1101/2020.02.04.20020479   NaN        NaN  medrvix   2020-02-05
# 2  10.1101/2020.02.24.20025437   NaN        NaN  medrvix   2020-02-26
# 3  10.1101/2020.02.22.20025460   NaN        NaN  medrvix   2020-02-23
# 4    10.1101/2020.03.13.991307   NaN        NaN  biorxiv   2020-03-14
#
#                                              authors journal  \
# 0  Hanchu Zhou; Jianan Yang; Kaichen Tang; Qingpe...     NaN
# 1  Shengjie Lai; Isaac Bogoch; Nick Ruktanonchai;...     NaN
# 2  Xiaoyang Ji; Chunming Zhang; Yubo Zhai; Zhongh...     NaN
# 3  Tieying Hou; Weiqi Zeng; Minling Yang; Wenjing...     NaN
# 4  Timothy R. Abbott; Girija Dhamdhere; Yanxia Li...     NaN
#
#    Microsoft Academic Paper ID WHO #Covidence has_full_text   full_text_file  \
# 0                          NaN            NaN          True  biorxiv_medrxiv
# 1                          NaN            NaN          True  biorxiv_medrxiv
# 2                          NaN            NaN          True  biorxiv_medrxiv
# 3                          NaN            NaN          True  biorxiv_medrxiv
# 4                          NaN            NaN          True  biorxiv_medrxiv
#
#    is_covid                                  preproc_body_text  \
# 0      True  the 2019-ncov epidemic has spread across china...
# 1      True  in december 2019 a cluster of patients with pn...
# 2      True  the sudden outbreak of the new coronavirus sar...
# 3      True  since the beginning of 2020 a surging number o...
# 4      True  the world is currently faced with a pandemic o...
#
#                                     body_text_parags
# 0  ['the 2019 - ncov epidemic has spread across c...
# 1  ['in december 2019 a cluster of patients with ...
# 2  ['the sudden outbreak of the new coronavirus s...
# 3  ['since the beginning of 2020 a surging number...
# 4  ['the world is currently faced with a pandemic...

# %%
SUMMARY_LENGTH = 12  # number of sentences in final summary
stop_words = stopwords.words('english')

# %%
class Summarizer():

    def penn_to_wn(self,tag):
        
        if tag.startswith('N'):
            return 'n'
 
        if tag.startswith('V'):
        
            return 'v'
 
        if tag.startswith('J'):
            return 'a'
 
        if tag.startswith('R'):
            return 'r'
        return None 
 

    def tagged_to_synset(self,word, tag):
        wn_tag = self.penn_to_wn(tag)
    
        if wn_tag is None:
            return None
 
        try:
        
            return wn.synsets(word, wn_tag)[0]
        except:
            return None
 
    def sentence_similarity(self,sentence1, sentence2):
       
        # Tokenize and tag
        sentence1 = pos_tag(word_tokenize(sentence1))
        
        sentence2 = pos_tag(word_tokenize(sentence2))
      
 
        # Get the synsets for the tagged words
        synsets1 = [self.tagged_to_synset(*tagged_word) for tagged_word in sentence1]
        
        synsets2 = [self.tagged_to_synset(*tagged_word) for tagged_word in sentence2]
       
 
    # Filter out the Nones
        synsets1 = [ss for ss in synsets1 if ss]
      
        synsets2 = [ss for ss in synsets2 if ss]
        
 
        score, count = 0, 0
        for synset in synsets1:
            max_sim = 0.0
            maxx=0
            for ss in synsets2:
                
                sim=wn.path_similarity(synset, ss)
                if sim is not None and sim > max_sim:
                
                       max_sim = sim
                   
           
        
            if max_sim is not None and max_sim!=0:
                score += max_sim
                count += 1
 
    # Average the values
        if count!=0:
            score /= count
            return score   
    def __init__(self, article):
            self._articles = []
            i=1
           
            for row in article:
                #if i<=5:
                    title=row[3]
                    #print(title)
                    body=row[17].replace('\n', ' ')
                    #print(body)
                    paper_id=row[0]
                    doi=row[5]
                    if title!=''and body!='':
                        self._articles.append((paper_id,title,body,doi))
                 #   i=i+1
            
            
    def valid_input(self, headline, article_text):
        return headline != '' and article_text != ''    
    def normalize_corpus(self,corpus, lemmatize=True):
        
        normalized_corpus = []    
        for text in corpus:
            if lemmatize:
                text = self.lemmatize_text(text)
            else:
                text = text.lower()
            text = self.remove_special_characters(text)
            text = self.remove_stopwords(text)
            normalized_corpus.append(text)
        return normalized_corpus
    def pos_tag_text(self,text):
        wnl = WordNetLemmatizer()
        tagged_text = tag(text)
        tagged_lower_text = [(word.lower(), self.penn_to_wn(pos_tag))
                             for word, pos_tag in
                             tagged_text]
        return tagged_lower_text
        
         
    def score(self,article,query):
        """ Assign each sentence in the document a score"""
        Query=[]
        Query.append(query)
        headline = article[1]
        #sentences = self.split_into_sentences(article[2])
        sentences=self.split_into_sentences(article[2])
        norm_corpus =self.normalize_corpus(sentences, lemmatize=True)
        #print(norm_corpus)
        # normalize model_answer
        norm_model_answer =  self.normalize_corpus(Query, lemmatize=True)   
        vectorizer, corpus_features = self.build_feature_matrix(norm_corpus,feature_type='frequency')
        # extract features from model_answer
        model_answer_features = vectorizer.transform(norm_model_answer)

        doc_lengths = [len(doc.split()) for doc in norm_corpus]   
        avg_dl = np.average(doc_lengths) 
        corpus_term_idfs = self.compute_corpus_term_idfs(corpus_features, norm_corpus)
        for index, doc in enumerate(Query):

            doc_features = model_answer_features[index]
            self.bm25_scores = self.compute_bm25_similarity(doc_features,corpus_features,doc_lengths,avg_dl,corpus_term_idfs,k1=1.5, b=0.75)
            self.semantic_similarity_scores=[]
        for i, s in enumerate(sentences):
                score1=self.sentence_similarity(s,query)
                score2=self.sentence_similarity(query,s)
                if score1 is not None and score2 is not None:
                    score=(score1+score2)/2
                    self.semantic_similarity_scores.append(score)
                elif score1 is not None and score2 is None:
                    self.semantic_similarity_scores.append(score1)
                elif score2 is not None and score1 is None:
                    self.semantic_similarity_scores.append(score2)
        doc_index=0
        sim_score=[]
        for score_tuple in zip(self.semantic_similarity_scores,self.bm25_scores):
            sim_score.append(((score_tuple[0])+score_tuple[1]/10)/2)
        for tuple_ in zip(sentences,sim_score):
            s=tuple_[0]
            self._scores[s]=tuple_[1]
        
        
                    
              
    def generate_summaries(self):
        
            self.dict_ = {'task':[],'doi':[],'paper_id':[],'title':[],'summary': [],'score':[],'sentences':[]}
            jj=1
            ii=1
          
            tasks=['what is the immune system response to 2019-ncov ?'
                   
                   ]
           
    
            for query in tasks:
                for article in self._articles:
                    self._scores = Counter()
                    self.score(article,query)
                    highest_scoring = self._scores.most_common(SUMMARY_LENGTH)
                    #totalsentences = splitParagraph(article[2])
                    #summarylist=[]
                    #summr=[sent[0] for sent[0] in highest_scoring]
                   
                    #for sentence in totalsentences:
                     #   for sumsen in  summr:
                      #      if sentence==sumsen:
                       #         summarylist.append(sentence)        
                    # Appends highest scoring "representative" sentences, returns as a single summary paragraph.
                    summary=' '.join([sent[0] for sent in highest_scoring])
                    s=0
                    for scr in highest_scoring:
                        s=s+scr[1]
                    s=s/12    
                    
                    
                    ''' 
                    print('**task**')
                    print(query)
                    print(" **Title: **")
                    print(article[1])
                    print(highest_scoring)
                    print('**summary**')
                    print(summary)
                    print('____________________________________________________________________________________')
                    '''   
                    
                    self.dict_['sentences'].append(highest_scoring)
                    self.dict_['summary'].append(summary)
                    self.dict_['title'].append(article[1])
                    self.dict_['paper_id'].append(article[0])
                    self.dict_['task'].append(query)
                    self.dict_['doi'].append(article[3])
                    self.dict_['score'].append(s)
            self.papers = pd.DataFrame(self.dict_, columns=['task','paper_id','doi','title','summary','score','sentences'])
            return self.papers
       

    def remove_smart_quotes(self, text):
       
       
        #text=re.sub("([\(\[].*?[\)\]][\(\[].*?[\)\]]+)", ' ', text)
        text=re.sub("[\(\[].*?[\)\]]", '', text)
        
        try:
            url = re.search(r'((https*:\/*)([^\/\s]+))(.[^\s]+)', text)
            repl_url = url.group(3)
            text = re.sub(r'((https*:\/*)([^\/\s]+))(.[^\s]+)',repl_url, text)
        except:
            pass #there might be emails with no url in them
        #text=re.sub("[\[]()*?[\]]", "", text)#remove in-text citation
        
        text=re.sub(r"[<>()(,)|&©ø\[\]\'\";?~*!]", ' ', text) #remove <>()|&©ø"',;?~*!
        text=re.sub("(\\t)", ' ', text) #remove escape charecters
        text=re.sub("(\\r)", ' ', text) 
        text=re.sub("(\\n)", ' ', text)
        text= re.sub("(\s+)",' ',text) #remove multiple space
        text=re.sub("doi", ' ',text)
        
        return text


    def split_into_sentences(self, text):
        tok = nltk.data.load('tokenizers/punkt/english.pickle')
        sentences = tok.tokenize(text)
        sentences = [sent.replace('\n', '') for sent in sentences if len(sent) > 20]   
        words=['author','authors''permissions','doi']
        
                 

        return sentences
    def lemmatize_text(self,text):
    
        pos_tagged_text = self.pos_tag_text(text)
        lemmatized_tokens = [wnl.lemmatize(word, pos_tag) if pos_tag
                             else word                     
                             for word, pos_tag in pos_tagged_text]
        lemmatized_text = ' '.join(lemmatized_tokens)
        return lemmatized_text

    def remove_special_characters(self,text):
        tokens = self.tokenize_text(text)
        pattern = re.compile('[{}]'.format(re.escape(string.punctuation)))
        filtered_tokens = filter(None, [pattern.sub(' ', token) for token in tokens])
        filtered_text = ' '.join(filtered_tokens)
        return filtered_text

    def remove_stopwords(self,text):
        stopword_list = nltk.corpus.stopwords.words('english')
        tokens = self.tokenize_text(text)
        filtered_tokens = [token for token in tokens if token not in stopword_list]
        filtered_text = ' '.join(filtered_tokens)    
        return filtered_text

    
  
    def build_feature_matrix(self,documents, feature_type='frequency',
                         ngram_range=(1, 1), min_df=0.0, max_df=1.0):

        feature_type = feature_type.lower().strip()  
    
        if feature_type == 'binary':
            vectorizer = CountVectorizer(binary=True, min_df=min_df,
                                     max_df=max_df, ngram_range=ngram_range)
        elif feature_type == 'frequency':
            vectorizer = CountVectorizer(binary=False, min_df=min_df,
                                     max_df=max_df, ngram_range=ngram_range)
        elif feature_type == 'tfidf':
            vectorizer = TfidfVectorizer(min_df=min_df, max_df=max_df, 
                                     ngram_range=ngram_range)
        else:
            raise Exception("Wrong feature type entered. Possible values: 'binary', 'frequency', 'tfidf'")

        feature_matrix = vectorizer.fit_transform(documents).astype(float)
    
        return vectorizer, feature_matrix

    def compute_corpus_term_idfs(self,corpus_features, norm_corpus):
    
        dfs = np.diff(sp.csc_matrix(corpus_features, copy=True).indptr)
        dfs = 1 + dfs # to smoothen idf later
        total_docs = 1 + len(norm_corpus)
        idfs = 1.0 + np.log(float(total_docs) / dfs)
        return idfs
    def compute_bm25_similarity(self,doc_features, corpus_features,
                            corpus_doc_lengths, avg_doc_length,
                            term_idfs, k1=1.5, b=0.75):
    # get corpus bag of words features
        corpus_features = corpus_features.toarray()
    # convert query document features to binary features
    # this is to keep a note of which terms exist per document
        doc_features = doc_features.toarray()[0]
        doc_features[doc_features >= 1] = 1
    
    # compute the document idf scores for present terms
        doc_idfs = doc_features * term_idfs
    # compute numerator expression in BM25 equation
        numerator_coeff = corpus_features * (k1 + 1)
        numerator = np.multiply(doc_idfs, numerator_coeff)
    # compute denominator expression in BM25 equation
        denominator_coeff =  k1 * (1 - b + 
                                (b * (corpus_doc_lengths / 
                                        avg_doc_length)))
        denominator_coeff = np.vstack(denominator_coeff)
        denominator = corpus_features + denominator_coeff
    # compute the BM25 score combining the above equations
        bm25_scores = np.sum(np.divide(numerator,
                                   denominator),
                         axis=1) 
    
        return bm25_scores
    def tokenize_text(self,text):
        tokens = nltk.word_tokenize(text) 
        tokens = [token.strip() for token in tokens]
        return tokens

# %%
import csv
import nltk
csv.field_size_limit(100000000)
results=pd.DataFrame()
f= open("sabrina.csv", encoding="utf-8-sig")
reader = csv.reader(f, delimiter=',')
next(reader)
summaries= Summarizer(reader)
results=summaries.generate_summaries()
resultss = results.sort_values(by='score', ascending=False)
resultss.head(50)
# Out:
#                                                    task  \
# 822   what is the immune system response to 2019-ncov ?
# 759   what is the immune system response to 2019-ncov ?
# 902   what is the immune system response to 2019-ncov ?
# 1232  what is the immune system response to 2019-ncov ?
# 898   what is the immune system response to 2019-ncov ?
# 943   what is the immune system response to 2019-ncov ?
# 622   what is the immune system response to 2019-ncov ?
# 765   what is the immune system response to 2019-ncov ?
# 777   what is the immune system response to 2019-ncov ?
# 475   what is the immune system response to 2019-ncov ?
# 807   what is the immune system response to 2019-ncov ?
# 904   what is the immune system response to 2019-ncov ?
# 545   what is the immune system response to 2019-ncov ?
# 509   what is the immune system response to 2019-ncov ?
# 626   what is the immune system response to 2019-ncov ?
# 482   what is the immune system response to 2019-ncov ?
# 1037  what is the immune system response to 2019-ncov ?
# 1146  what is the immune system response to 2019-ncov ?
# 1285  what is the immune system response to 2019-ncov ?
# 405   what is the immune system response to 2019-ncov ?
# 613   what is the immune system response to 2019-ncov ?
# 695   what is the immune system response to 2019-ncov ?
# 687   what is the immune system response to 2019-ncov ?
# 497   what is the immune system response to 2019-ncov ?
# 551   what is the immune system response to 2019-ncov ?
# 751   what is the immune system response to 2019-ncov ?
# 682   what is the immune system response to 2019-ncov ?
# 966   what is the immune system response to 2019-ncov ?
# 453   what is the immune system response to 2019-ncov ?
# 602   what is the immune system response to 2019-ncov ?
# 644   what is the immune system response to 2019-ncov ?
# 1133  what is the immune system response to 2019-ncov ?
# 1170  what is the immune system response to 2019-ncov ?
# 688   what is the immune system response to 2019-ncov ?
# 1106  what is the immune system response to 2019-ncov ?
# 1150  what is the immune system response to 2019-ncov ?
# 731   what is the immune system response to 2019-ncov ?
# 661   what is the immune system response to 2019-ncov ?
# 526   what is the immune system response to 2019-ncov ?
# 518   what is the immune system response to 2019-ncov ?
# 658   what is the immune system response to 2019-ncov ?
# 1161  what is the immune system response to 2019-ncov ?
# 44    what is the immune system response to 2019-ncov ?
# 470   what is the immune system response to 2019-ncov ?
# 619   what is the immune system response to 2019-ncov ?
# 1224  what is the immune system response to 2019-ncov ?
# 559   what is the immune system response to 2019-ncov ?
# 514   what is the immune system response to 2019-ncov ?
# 488   what is the immune system response to 2019-ncov ?
# 555   what is the immune system response to 2019-ncov ?
#
#                                       paper_id  \
# 822   40dabecefc2f0a2b750e000d1c15cca57a3f7dd4
# 759   2008f024274c53b0de1276f4047a6a641813fd98
# 902   6aadca94314fe7e81e278fbbef178f2a5bf4f538
# 1232  fea50730d7cdcd7c728f98c31fe20aeb8af5e350
# 898   68ac63121bded12e1db3178a0c9b050154f81ab8
# 943   78e39a957cc704ddc919e704459258e55178f574
# 622   b30770ae30b35cdfaf0a173863e74e93edbb0329
# 765   2437ecdfe29ce5195079af809de646e9e1e1350a
# 777   2c66349f1922022b585ae0e5d6c0776c27d2852d
# 475   1ddf28f6c2bc0a7db607b0771748e34fb6659f51
# 807   39a3c99814a041252c86cfcf914e729429f46ffb
# 904   6be4fe1605ea1a6f558204da253019a399be3178
# 545   66a6a5cb7b41fb6edd030629be7c455c079f47bf
# 509   489040d34aa5dc8e6eba3d4e9d3d48f0bcc6061f
# 626   b7b6bf20c919a0b200c528e76f76f508d5554700
# 482   250c1f24a22bcb81973ea532f8236838987e0872
# 1037  a1caca4867233cd8f16de938ef36e2de365a95ba
# 1146  d817da9fc7dd94d21db3b72baa274a6cb924ee7a
# 1285  8cd6d7c2eeb732eeecb6b7618d02eafe82aa62a4
# 405   f08249cbb9bdfc3b7f103470537a52190c81b974
# 613   a81fbdb3bc7956412cd686e72115f4cddf1090be
# 695   00a0ab182dc01b6c2e737dfae585f050dcf9a7a5
# 687   f5e974ef3a8c983ae63ac4f4aa2b6ec0e3678032
# 497   3a39684ab2bd22b39597a985ed3c57794a941a82
# 551   6c3e1a43f0e199876d4bd9ff787e1911fd5cfaa6
# 751   1b699edbd45249b3ffc2809281c2bf75c42cd70d
# 682   f046ba37a3a60a90b3dbcc977182efe1672ba300
# 966   83a5cb9fca2a2cbcd33ec7b1039bb514fae49095
# 453   09de57e5401565a1e80361d32b09ce66b3a988c8
# 602   9b0c87f808b1b66f2937d7a7acb524a756b6113b
# 644   c99be1ffda777de5b7f9e0ed6c04fd70ce0bc3e1
# 1133  d202a1d1765204bdba9fa46aa07293a30e9d2188
# 1170  e49d667052fcc5adb2ed3b73da59785855a94384
# 688   f76f29653d5c53667e4a9615ca50f8b94c753d36
# 1106  c4715a43fd47ecc7b26f1a49db4e93fa397a258d
# 1150  d99fcb854ef8540ba535e65784ec9d9a7fe45159
# 731   12168cb2a6c74ba276aab057f2728c9abe1f85df
# 661   d955f71fe354a87e671999a6a0a17b88376bcf8c
# 526   54ca96205e785170fff9f439860d4f4fa4d95782
# 518   50c268968326f133eeacd3745e43a4226d867ce8
# 658   d16e1bd4c6cae1bb55dbc695c5e2ba5105a13921
# 1161  de64983bd4eb6f372ec3d1ac74511ee433632e20
# 44    181b7b57851e6f58a601b68e613d10c10616f774
# 470   1986e96f2be6bd012fcd4d0b731caf62c7a4dea2
# 619   ac6b3fe26ffb1e6b3b34200c9053a724e81f2d7a
# 1224  fcbc3f7f4fd4a27c9010c4bea83c41a224d4530f
# 559   779c1b5cb3afe3d50219aa2af791014a22eb355a
# 514   4e6709b68cb7312fda8a1c5a2b2505d21a38a1e9
# 488   2d266d6c9ef81ffefa8fc5ba319851d220e71cbd
# 555   75c2dba50049d4ee01ac711d152c62b018f31cf9
#
#                                      doi  \
# 822         10.1016/0163-7258(85)90033-6
# 759        10.1016/S1081-1206(10)61294-X
# 902                      10.1186/cc13531
# 1232    10.1016/j.compbiomed.2020.103670
# 898           10.1016/j.mehy.2015.11.005
# 943           10.1016/j.prrv.2008.05.005
# 622            10.1186/s13054-016-1208-6
# 765     10.1016/B978-012373944-5.00314-X
# 777     10.1016/B978-012369454-6/50034-0
# 475             10.3389/fmicb.2020.00298
# 807          10.1016/j.jprot.2019.103527
# 904   10.1016/B978-0-12-385885-6.00009-2
# 545            10.1186/s13567-018-0578-y
# 509
# 626         10.1371/journal.ppat.1004113
# 482            10.1186/s12879-016-1877-4
# 1037      10.1016/j.virusres.2014.09.016
# 1146       10.1016/S0165-2427(01)00386-5
# 1285
# 405          10.1101/2020.03.15.20033472
# 613             10.3389/fimmu.2018.02052
# 695       10.1016/j.virusres.2015.01.021
# 687                     10.3390/v4060980
# 497            10.1186/s40168-017-0395-y
# 551                 10.1155/2019/8567364
# 751         10.1016/bs.aivir.2016.08.002
# 682                  10.7554/eLife.12469
# 966        10.1016/S0168-1656(01)00281-4
# 453                    10.3390/v12030254
# 602                   10.3390/jcm9030623
# 644         10.1371/journal.ppat.0030109
# 1133          10.1016/j.chom.2020.03.002
# 1170        10.1016/0378-1135(93)90126-R
# 688         10.1371/journal.ppat.1006195
# 1106       10.1016/S1525-1578(15)00191-9
# 1150        10.1016/j.meegid.2020.104215
# 731        10.1016/S0169-409X(02)00145-X
# 661         10.1371/journal.pgen.1006467
# 526           10.2174/138920312804871102
# 518           10.1038/s41598-019-51679-8
# 658                10.1186/1465-9921-6-8
# 1161       10.1016/S0952-7915(96)80019-7
# 44             10.1101/2020.02.03.933226
# 470                     10.3390/v7072786
# 619
# 1224         10.1016/j.virol.2010.11.014
# 559                    10.3390/v12020194
# 514         10.1371/journal.pone.0070129
# 488         10.1371/journal.pone.0078454
# 555                10.1128/mBio.01422-18
#
#                                                   title  \
# 822   ANIMAL VIRUSES OF ECONOMIC IMPORTANCE: GENETIC...
# 759                      ABSTRACTS: CONCURRENT SESSIONS
# 902   Minimising prescribing errors in the ICU DJ Me...
# 1232  Computers and viral diseases. Preliminary bioi...
# 898   Seasonality and selective trends in viral acut...
# 943   Innate immune response and bronchiolitis and p...
# 622   P001 Sepsis impairs the capillary response wit...
# 765                                 Respiratory Viruses
# 777                     Chapter 6 Mouse Hepatitis Virus
# 475   Subunit Vaccines Against Emerging Pathogenic H...
# 807   Quantitative label-free proteomic analysis rev...
# 904                            Coronavirus Pathogenesis
# 545   Characterization of peritoneal cells from cats...
# 509   Open Peer Review Therapeutic strategies in an ...
# 626   Structural Basis for the Ubiquitin-Linkage Spe...
# 482   Pathogenesis of bacterial infections A1 The ou...
# 1037  Coronavirus-induced ER stress response and its...
# 1146  Isotype-speci®c antibody-secreting cells in sy...
# 1285  Viral Infection of Transgenic Mice Expressing ...
# 405   Blood single cell immune profiling reveals the...
# 613   The Journey of in vivo Virus Engineered Dendri...
# 695   Middle East respiratory syndrome: An emerging ...
# 687   Recent Progress in Studies of Arterivirus-and ...
# 497   Haemophilus is overrepresented in the nasophar...
# 551   Review Article Microbial Agents as Putative In...
# 751   Feline Coronaviruses: Pathogenesis of Feline I...
# 682   Viruses are a dominant driver of protein adapt...
# 966              Coronavirus derived expression systems
# 453   Preliminary Identification of Potential Vaccin...
# 602   Potential Rapid Diagnostics, Vaccine and Thera...
# 644   Coronavirus Non-Structural Protein 1 Is a Majo...
# 1133  A Sequence Homology and Bioinformatic Approach...
# 1170  A review of feline infectious peritonitis viru...
# 688   Early endonuclease-mediated evasion of RNA sen...
# 1106  GENETICS G01. C9orf72 GGGGCC Expansion Frequen...
# 1150  Pathogenic viruses: Molecular detection and ch...
# 731   B arriers to and new approaches for gene thera...
# 661   Allelic Variation in CXCL16 Determines CD3 + T...
# 526   Send Orders of Reprints at bspsaif@emirates.ne...
# 518   In silico/In vivo analysis of high-risk papill...
# 658   Respiratory Research Molecular mechanisms of s...
# 1161                   Virus-induced autoimmune disease
# 44    Preliminary identification of potential vaccin...
# 470   Relevance of Viroporin Ion Channel Activity on...
# 619   Original Chemical Series of Pyrimidine Biosynt...
# 1224  Phage displayed peptides recognizing porcine a...
# 559   viruses Perspective Potential Maternal and Inf...
# 514   Human Coronavirus HKU1 Infection of Primary Hu...
# 488   Autologous Antibody Capture to Enrich Immunoge...
# 555   Reverse Genetics for Type I Feline Coronavirus...
#
#                                                 summary     score  \
# 822   in broad terms the immune system among vertebr...  0.927862
# 759   a defect of the innate immune system more part...  0.764587
# 902   also in these patients cortisol correlates to ...  0.763463
# 1232  cysteine c should be avoided perhaps replaced ...  0.744909
# 898   although heat stress may boost the immune syst...  0.724500
# 943   they help to initiate the innate immune respon...  0.715214
# 622   the introduction: neutrophil extracellular tra...  0.711257
# 765   the type of immune response to hrsv is a major...  0.699110
# 777   mhv and neurotropic mhv-jhm in particular or v...  0.680220
# 475   vaccination pathways are important in inducing...  0.675860
# 807   deps related to the immune response were ident...  0.675405
# 904   multiple sars-cov proteins have been reported ...  0.675282
# 545   fc receptors have been shown to be important r...  0.665788
# 509   patients with resolved viral infection will de...  0.664695
# 626   though the exact outcome of plpro s deisgylati...  0.649212
# 482   host immune response to the viral infection mi...  0.646618
# 1037  involvement of upr in innate immune response d...  0.645361
# 1146  however these young animals in spite of having...  0.638510
# 1285  first the immune response to lcmv has been wel...  0.637977
# 405   in conclusion in this study we revealed the im...  0.634452
# 613   moreover the pre-existing antiviral response w...  0.632046
# 695   these cells are needed to see the full extent ...  0.629805
# 687   these tactics range from the prevention of det...  0.628557
# 497   this suggests that the type of alteration of t...  0.626349
# 551   among these lymphotoxin-α lta is particularly ...  0.621509
# 751   the development of the various clinical forms ...  0.620873
# 682   the final set of immune vips is made of the 20...  0.617615
# 966   these amounts have been sufficient to elicit s...  0.611332
# 453   despite having limited understanding of how th...  0.604995
# 602   in addition most of those who have died from m...  0.603822
# 644   however recent concepts in immunology provide ...  0.599358
# 1133  the immune response to sars-cov-2 in humans aw...  0.598852
# 1170  it has been hypothesized that because of a lac...  0.598809
# 688   coronaviruses have long been known to efficien...  0.597955
# 1106  introduction: primary immunodeficiencies pids ...  0.597150
# 1150  the 2019 novel coronavirus 2019-ncov which eme...  0.596233
# 731   some reports have indicated that stimulation o...  0.596221
# 661   this is despite the fact that carrier stallion...  0.593830
# 526   pathogen-derived proteases range from nonspeci...  0.593478
# 518   netlogo is an agent-based modeling of the immu...  0.592711
# 658   this vaccine was shown to initiate both humora...  0.592288
# 1161  specific antiviral therapies that inhibit vira...  0.591868
# 44    despite having limited understanding of how th...  0.588941
# 470   over stimulation of immune responses can also ...  0.583881
# 619   nevertheless the results obtained for rig-i if...  0.581323
# 1224  our findings are interesting and it seems that...  0.580958
# 559   it remains to be seen during the current wuhan...  0.580231
# 514   the innate immune system serves as the first l...  0.579163
# 488   these viruses are not known to elicit an immun...  0.578646
# 555   it is therefore tempting to speculate that the...  0.577069
#
#                                               sentences
# 822   [(in broad terms the immune system among verte...
# 759   [(a defect of the innate immune system more pa...
# 902   [(also in these patients cortisol correlates t...
# 1232  [(cysteine c should be avoided perhaps replace...
# 898   [(although heat stress may boost the immune sy...
# 943   [(they help to initiate the innate immune resp...
# 622   [(the introduction: neutrophil extracellular t...
# 765   [(the type of immune response to hrsv is a maj...
# 777   [(mhv and neurotropic mhv-jhm in particular or...
# 475   [(vaccination pathways are important in induci...
# 807   [(deps related to the immune response were ide...
# 904   [(multiple sars-cov proteins have been reporte...
# 545   [(fc receptors have been shown to be important...
# 509   [(patients with resolved viral infection will ...
# 626   [(though the exact outcome of plpro s deisgyla...
# 482   [(host immune response to the viral infection ...
# 1037  [(involvement of upr in innate immune response...
# 1146  [(however these young animals in spite of havi...
# 1285  [(first the immune response to lcmv has been w...
# 405   [(in conclusion in this study we revealed the ...
# 613   [(moreover the pre-existing antiviral response...
# 695   [(these cells are needed to see the full exten...
# 687   [(these tactics range from the prevention of d...
# 497   [(this suggests that the type of alteration of...
# 551   [(among these lymphotoxin-α lta is particularl...
# 751   [(the development of the various clinical form...
# 682   [(the final set of immune vips is made of the ...
# 966   [(these amounts have been sufficient to elicit...
# 453   [(despite having limited understanding of how ...
# 602   [(in addition most of those who have died from...
# 644   [(however recent concepts in immunology provid...
# 1133  [(the immune response to sars-cov-2 in humans ...
# 1170  [(it has been hypothesized that because of a l...
# 688   [(coronaviruses have long been known to effici...
# 1106  [(introduction: primary immunodeficiencies pid...
# 1150  [(the 2019 novel coronavirus 2019-ncov which e...
# 731   [(some reports have indicated that stimulation...
# 661   [(this is despite the fact that carrier stalli...
# 526   [(pathogen-derived proteases range from nonspe...
# 518   [(netlogo is an agent-based modeling of the im...
# 658   [(this vaccine was shown to initiate both humo...
# 1161  [(specific antiviral therapies that inhibit vi...
# 44    [(despite having limited understanding of how ...
# 470   [(over stimulation of immune responses can als...
# 619   [(nevertheless the results obtained for rig-i ...
# 1224  [(our findings are interesting and it seems th...
# 559   [(it remains to be seen during the current wuh...
# 514   [(the innate immune system serves as the first...
# 488   [(these viruses are not known to elicit an imm...
# 555   [(it is therefore tempting to speculate that t...

# %%
resultss.to_csv('sentences.csv', index=False)
res=pd.read_csv('sentences.csv')
res.head()
# Out:
#                                                 task  \
# 0  what is the immune system response to 2019-ncov ?
# 1  what is the immune system response to 2019-ncov ?
# 2  what is the immune system response to 2019-ncov ?
# 3  what is the immune system response to 2019-ncov ?
# 4  what is the immune system response to 2019-ncov ?
#
#                                    paper_id                               doi  \
# 0  40dabecefc2f0a2b750e000d1c15cca57a3f7dd4      10.1016/0163-7258(85)90033-6
# 1  2008f024274c53b0de1276f4047a6a641813fd98     10.1016/S1081-1206(10)61294-X
# 2  6aadca94314fe7e81e278fbbef178f2a5bf4f538                   10.1186/cc13531
# 3  fea50730d7cdcd7c728f98c31fe20aeb8af5e350  10.1016/j.compbiomed.2020.103670
# 4  68ac63121bded12e1db3178a0c9b050154f81ab8        10.1016/j.mehy.2015.11.005
#
#                                                title  \
# 0  ANIMAL VIRUSES OF ECONOMIC IMPORTANCE: GENETIC...
# 1                     ABSTRACTS: CONCURRENT SESSIONS
# 2  Minimising prescribing errors in the ICU DJ Me...
# 3  Computers and viral diseases. Preliminary bioi...
# 4  Seasonality and selective trends in viral acut...
#
#                                              summary     score  \
# 0  in broad terms the immune system among vertebr...  0.927862
# 1  a defect of the innate immune system more part...  0.764587
# 2  also in these patients cortisol correlates to ...  0.763463
# 3  cysteine c should be avoided perhaps replaced ...  0.744909
# 4  although heat stress may boost the immune syst...  0.724500
#
#                                            sentences
# 0  [('in broad terms the immune system among vert...
# 1  [('a defect of the innate immune system more p...
# 2  [('also in these patients cortisol correlates ...
# 3  [('cysteine c should be avoided perhaps replac...
# 4  [('although heat stress may boost the immune s...

# %%
corpus=[]
scores = Counter()

for i in range(len(resultss)):
    
        
        for x in resultss.sentences[i]:
        
            corpus.append(x)

# %%
scores = Counter()
for item in corpus:
    #print(item[0])
    s=item[0]
    scores[s]=item[1]

# %%
highest_scoring =scores.most_common(20)
                    
summr=[sent[0] for sent in highest_scoring]
                   

summary=' '.join([sent for sent in  summr])
print(summary)
# Out:
# in terms of the human immune system the innate immune system response plays an important role in controlling the replication and infection of coronavirus and interferon is expected to enhance the immune response 11 . the final set of immune vips is made of the 203 vips annotated with the go categories immune system process go:0002376 defense response go:0006952 or immune response go:0006955 2015 in addition to 38 immune vips we annotated based on publications reporting roles in various parts of the immune response from innate to adaptive immune response from regulators to effectors of the immune response to vips involved in the development of the immune system. the immune response to 2019-ncov in humans awaits characterization but human immune responses against other coronaviruses have been investigated. in broad terms the immune system among vertebrates is similar especially in regard to immune responses to virus infections. fprs are involved in a variety of signaling systems and their distribution and functions are not limited to the immune system. gr is known to participate in an oxidative defence system required for effective immune responses against bacteria 14 15 . one other reason was the infection-mediated harmful immune response that caused the nervous system abnormalities. the extensive evolution of the torovirus he gene may have been a hostadaptation strategy or a way to evade the host immune response. multiple sars-cov proteins have been reported to interact with components of the innate immune system to evade an antiviral interferon response and these are discussed below with the individual proteins that have been implicated in this process. cysa is licensed for use in organ transplantation to suppress the immune response. on 21 january emergency response system was activated to better provide ongoing support to the covid-19 response 18 . although ang ii was originally described as an effective vasoconstrictor there is growing evidence that it is closely involved in the inflammatory response of the immune system. they help to initiate the innate immune response and mediate signalling between the innate and the adaptive immune system. thus an immune response is mounted. host immune response to the viral infection might be influenced by these antibodies. the innate immune system initiates defensive responses to infecting viruses and bacteria by recognition of pathogen associated molecular patterns pamps as non-self signatures. after 2019-ncov impairs the immune system it is difficult to prevent the is the author/funder who has granted medrxiv a license to display the preprint in perpetuity. these amounts have been sufficient to elicit strong immune responses. a defect of the innate immune system more particularly the complement system is the inciting culprit. allergy is acquired hypersensitivity reaction of immune response.

# %%
highest_scoring =scores.most_common(25)
                    
summr=[sent[0] for sent in highest_scoring]
                   

summary=' '.join([sent for sent in  summr])
print(summary)
# Out:
# in terms of the human immune system the innate immune system response plays an important role in controlling the replication and infection of coronavirus and interferon is expected to enhance the immune response 11 . the final set of immune vips is made of the 203 vips annotated with the go categories immune system process go:0002376 defense response go:0006952 or immune response go:0006955 2015 in addition to 38 immune vips we annotated based on publications reporting roles in various parts of the immune response from innate to adaptive immune response from regulators to effectors of the immune response to vips involved in the development of the immune system. the immune response to 2019-ncov in humans awaits characterization but human immune responses against other coronaviruses have been investigated. in broad terms the immune system among vertebrates is similar especially in regard to immune responses to virus infections. fprs are involved in a variety of signaling systems and their distribution and functions are not limited to the immune system. gr is known to participate in an oxidative defence system required for effective immune responses against bacteria 14 15 . one other reason was the infection-mediated harmful immune response that caused the nervous system abnormalities. the extensive evolution of the torovirus he gene may have been a hostadaptation strategy or a way to evade the host immune response. multiple sars-cov proteins have been reported to interact with components of the innate immune system to evade an antiviral interferon response and these are discussed below with the individual proteins that have been implicated in this process. cysa is licensed for use in organ transplantation to suppress the immune response. on 21 january emergency response system was activated to better provide ongoing support to the covid-19 response 18 . although ang ii was originally described as an effective vasoconstrictor there is growing evidence that it is closely involved in the inflammatory response of the immune system. they help to initiate the innate immune response and mediate signalling between the innate and the adaptive immune system. thus an immune response is mounted. host immune response to the viral infection might be influenced by these antibodies. the innate immune system initiates defensive responses to infecting viruses and bacteria by recognition of pathogen associated molecular patterns pamps as non-self signatures. after 2019-ncov impairs the immune system it is difficult to prevent the is the author/funder who has granted medrxiv a license to display the preprint in perpetuity. these amounts have been sufficient to elicit strong immune responses. a defect of the innate immune system more particularly the complement system is the inciting culprit. allergy is acquired hypersensitivity reaction of immune response. the host airway immune response was also evaluated significantly increased expression of immune response genes was detected in patients with confirmed lower respiratory tract pathogens. this might be due to a differential temporal response of the immune system as has been recognised in other infections i e ebv henle et al 1974 . alternatively an immune response might only be produced to one of them. however these young animals in spite of having a non-totally-mature-immune system are immunocompetent from the birth and are capable of developing a complete immune response roth 1999 . she reported on coronavirus phosphodiesterases antagonizing the innate immune response of the host.
